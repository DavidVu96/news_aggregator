# %%
from newsapi import NewsApiClient
from pprint import pprint

# %%
# Init
newsapi = NewsApiClient(api_key='c6edd7ed1db24b8485922e60c38c6930')

# %%
# /v2/top-headlines
top_headlines = newsapi.get_top_headlines(q='intel',
#                                           sources='bbc-news,the-verge',
                                          category='business',
                                          language='en',
                                          country='us')

# %%
# /v2/everything
all_articles = newsapi.get_everything(q='bitcoin',
                                      sources='bbc-news,the-verge',
                                      domains='bbc.co.uk,techcrunch.com',
                                      from_param='2017-12-01',
                                      to='2017-12-12',
                                      language='en',
                                      sort_by='relevancy',
                                      page=2)

# %%
# /v2/sources
sources = newsapi.get_sources()

# %%
sources.get('sources')
# Out:
# dict_keys(['status', 'sources'])

# %%
pprint(sources.get('sources'))
# Out:
# [{'category': 'general',
#   'country': 'us',
#   'description': 'Your trusted source for breaking news, analysis, exclusive '
#                  'interviews, headlines, and videos at ABCNews.com.',
#   'id': 'abc-news',
#   'language': 'en',
#   'name': 'ABC News',
#   'url': 'https://abcnews.go.com'},
#  {'category': 'general',
#   'country': 'au',
#   'description': "Australia's most trusted source of local, national and world "
#                  'news. Comprehensive, independent, in-depth analysis, the '
#                  'latest business, sport, weather and more.',
#   'id': 'abc-news-au',
#   'language': 'en',
#   'name': 'ABC News (AU)',
#   'url': 'http://www.abc.net.au/news'},
#  {'category': 'general',
#   'country': 'no',
#   'description': 'Norges ledende nettavis med alltid oppdaterte nyheter '
#                  'innenfor innenriks, utenriks, sport og kultur.',
#   'id': 'aftenposten',
#   'language': 'no',
#   'name': 'Aftenposten',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(sources.get('sources')).set_index('id')

# %%
df
# Out:
#                                   name  \
# id
# abc-news                      ABC News
# abc-news-au              ABC News (AU)
# aftenposten                Aftenposten
# al-jazeera-english  Al Jazeera English
# ansa                           ANSA.it
# ...                                ...
# wired                            Wired
# wired-de                      Wired.de
# wirtschafts-woche    Wirtschafts Woche
# xinhua-net                  Xinhua Net
# ynet                              Ynet
#
#                                                           description  \
# id
# abc-news            Your trusted source for breaking news, analysi...
# abc-news-au         Australia's most trusted source of local, nati...
# aftenposten         Norges ledende nettavis med alltid oppdaterte ...
# al-jazeera-english  News, analysis from the Middle East and worldw...
# ansa                Agenzia ANSA: ultime notizie, foto, video e ap...
# ...

# %%
english_df = df[df.language == 'en']

# %%
non_english_df = df[df.language != 'en']

# %%
non_english_df.describe()
# Out:
#                            name  \
# count                        47
# unique                       47
# top     Google News (Argentina)
# freq                          1
#
#                                               description  \
# count                                                  47
# unique                                                 47
# top     Copertura giornalistica completa e aggiornata ...
# freq                                                    1
#
#                             url category language country
# count                        47       47       47      47
# unique                       41        4       13      15
# top     https://news.google.com  general       de      de
# freq                          7       34       10      10

# %%
english_df
# Out:
#                                       name  \
# id
# abc-news                          ABC News
# abc-news-au                  ABC News (AU)
# al-jazeera-english      Al Jazeera English
# ars-technica                  Ars Technica
# associated-press          Associated Press
# ...                                    ...
# the-washington-times  The Washington Times
# time                                  Time
# usa-today                        USA Today
# vice-news                        Vice News
# wired                                Wired
#
#                                                             description  \
# id
# abc-news              Your trusted source for breaking news, analysi...
# abc-news-au           Australia's most trusted source of local, nati...
# al-jazeera-english    News, analysis from the Middle East and worldw...
# ars-technica          The PC enthusiast's resource. Power users and ...
# ...

# %%
tech_english_df = english_df[english_df.category == 'technology']

# %%
tech_english_df
# Out:
#                                 name  \
# id
# ars-technica            Ars Technica
# crypto-coins-news  Crypto Coins News
# engadget                    Engadget
# hacker-news              Hacker News
# recode                        Recode
# techcrunch                TechCrunch
# techradar                  TechRadar
# the-next-web            The Next Web
# the-verge                  The Verge
# wired                          Wired
#
#                                                          description  \
# id
# ars-technica       The PC enthusiast's resource. Power users and ...
# crypto-coins-news  Providing breaking cryptocurrency news - focus...
# engadget           Engadget is a web magazine with obsessive dail...
# hacker-news        Hacker News is a social news website focusing ...
# recode             Get the latest independent tech news, reviews ...
# techcrunch         TechCrunch is a leading technology media prope...
# ...

# %%
top_headlines.keys()
# Out:
# dict_keys(['status', 'totalResults', 'articles'])

# %%
top_headlines.get('totalResults')
# Out:
# 0

# %%
top_headlines.get('articles')
# Out:
# []
